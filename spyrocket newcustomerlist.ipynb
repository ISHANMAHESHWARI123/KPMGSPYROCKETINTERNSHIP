# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime,timedelta

# %%
df_n=pd.read_excel('spyrockett.xlsx',sheet_name='NewCustomerList',skiprows=1)

# %%
df_n.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
df_n.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
tmp=['first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
       'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value']
for i in tmp:
    print(i)
    print(df_n[i].value_counts())
    print(' ')
# Out:
# first_name
# Dorian      3
# Rozamond    3
# Mandie      3
# Feodor      2
# Bartram     2
#            ..
# Claudell    1
# Sumner      1
# Andy        1
# Barthel     1
# Park        1
# Name: first_name, Length: 940, dtype: int64
#
# last_name
# Sturch         2
# Borsi          2
# Eade           2
# Hallt          2
# Minshall       2
#               ..
# Wiszniewski    1
# Piecha         1
# Bergstram      1
# Gosnoll        1
# Andrejevic     1
# Name: last_name, Length: 961, dtype: int64
#
# gender
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64
#
# past_3_years_bike_related_purchases
# 60    20
# 59    18
# 70    17
# 42    17
# 37    16
#       ..
# 19     5
# 9      5
# 92     5
# 85     4
# 20     3
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64
#
# DOB
# 1961-07-31    2
# 1994-04-15    2
# 1987-01-15    2
# 1951-11-28    2
# 1979-07-28    2
#              ..
# 1947-04-21    1
# 1995-10-10    1
# 1964-08-23    1
# ...

# %%
df_n['gender'].replace({'Female':'F','Male':'M'},inplace=True)

# %%
tmp=['first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
       'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value']
for i in tmp:
    print(i)
    print(df_n[i].value_counts())
# Out:
# first_name
# Dorian      3
# Rozamond    3
# Mandie      3
# Feodor      2
# Bartram     2
#            ..
# Claudell    1
# Sumner      1
# Andy        1
# Barthel     1
# Park        1
# Name: first_name, Length: 940, dtype: int64
# last_name
# Sturch         2
# Borsi          2
# Eade           2
# Hallt          2
# Minshall       2
#               ..
# Wiszniewski    1
# Piecha         1
# Bergstram      1
# Gosnoll        1
# Andrejevic     1
# Name: last_name, Length: 961, dtype: int64
# gender
# F    513
# M    470
# U     17
# Name: gender, dtype: int64
# past_3_years_bike_related_purchases
# 60    20
# 59    18
# 70    17
# 42    17
# 37    16
#       ..
# 19     5
# 9      5
# 92     5
# 85     4
# 20     3
# Name: past_3_years_bike_related_purchases, Length: 100, dtype: int64
# DOB
# 1961-07-31    2
# 1994-04-15    2
# 1987-01-15    2
# 1951-11-28    2
# 1979-07-28    2
#              ..
# 1947-04-21    1
# 1995-10-10    1
# 1964-08-23    1
# 1962-05-12    1
# ...

# %%
# df['DOB']=pd.to_datetime(df['DOB'],format='%d/%m/%Y')
# df1['age']=(datetime.today()[0]-df['DOB'][0]).days
# df['age']

# %%
df_n.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Unnamed: 16                                   float64
# ...

# %%
df_n.describe(include='all')
# Out:
#        first_name last_name gender  past_3_years_bike_related_purchases  \
# count        1000       971   1000                          1000.000000
# unique        940       961      3                                  NaN
# top        Dorian    Sturch      F                                  NaN
# freq            3         2    513                                  NaN
# first         NaN       NaN    NaN                                  NaN
# last          NaN       NaN    NaN                                  NaN
# mean          NaN       NaN    NaN                            49.836000
# std           NaN       NaN    NaN                            27.796686
# min           NaN       NaN    NaN                             0.000000
# 25%           NaN       NaN    NaN                            26.750000
# 50%           NaN       NaN    NaN                            51.000000
# 75%           NaN       NaN    NaN                            72.000000
# ...

# %%
df_n.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
df_n.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Unnamed: 16                                   float64
# ...

# %%
tmp=['last_name','DOB','job_title','job_industry_category']
for i in tmp:
    print(df_n[i].mode())
# Out:
# 0            Borsi
# 1         Burgoine
# 2          Crellim
# 3             Eade
# 4            Hallt
# 5         Minshall
# 6        Shoesmith
# 7           Sissel
# 8           Sturch
# 9    Van den Velde
# dtype: object
# 0    1941-07-21
# 1    1945-06-11
# 2    1951-04-29
# 3    1951-04-30
# 4    1951-11-28
# 5    1955-11-25
# 6    1959-08-01
# 7    1959-09-18
# 8    1961-07-31
# 9    1963-08-25
# 10   1965-07-03
# 11   1966-01-02
# 12   1971-04-26
# 13   1974-12-25
# 14   1977-11-08
# 15   1978-01-15
# 16   1978-12-14
# 17   1979-07-28
# 18   1987-01-15
# 19   1992-10-13
# 20   1993-11-02
# 21   1994-04-15
# 22   1995-08-13
# 23   1997-10-23
# 24   1998-02-05
# dtype: datetime64[ns]
# 0    Associate Professor
# dtype: object
# 0    Financial Services
# dtype: object

# %%
df_n['DOB'].mode()
# Out:
# 0    1941-07-21
# 1    1945-06-11
# 2    1951-04-29
# 3    1951-04-30
# 4    1951-11-28
# 5    1955-11-25
# 6    1959-08-01
# 7    1959-09-18
# 8    1961-07-31
# 9    1963-08-25
# 10   1965-07-03
# 11   1966-01-02
# 12   1971-04-26
# 13   1974-12-25
# 14   1977-11-08
# 15   1978-01-15
# 16   1978-12-14
# 17   1979-07-28
# 18   1987-01-15
# 19   1992-10-13
# 20   1993-11-02
# 21   1994-04-15
# 22   1995-08-13
# 23   1997-10-23
# 24   1998-02-05
# dtype: datetime64[ns]

# %%
df_n['job_title'].fillna('Associate Professor',inplace=True)

# %%
df_n['job_industry_category'].fillna('Financial Services',inplace=True)

# %%
df_n.isnull().sum()
# Out:
# first_name                              0
# last_name                              29
# gender                                  0
# past_3_years_bike_related_purchases     0
# DOB                                    17
# job_title                               0
# job_industry_category                   0
# wealth_segment                          0
# deceased_indicator                      0
# owns_car                                0
# tenure                                  0
# address                                 0
# postcode                                0
# state                                   0
# country                                 0
# property_valuation                      0
# Unnamed: 16                             0
# Unnamed: 17                             0
# Unnamed: 18                             0
# Unnamed: 19                             0
# Unnamed: 20                             0
# Rank                                    0
# ...

# %%
df_n['last_name'].fillna('np.NaN',inplace=True)

# %%
# df_n['DOB'].fillna('np.NaN',inplace=True)

# %%
df_n.isnull().sum()
# Out:
# first_name                              0
# last_name                               0
# gender                                  0
# past_3_years_bike_related_purchases     0
# DOB                                    17
# job_title                               0
# job_industry_category                   0
# wealth_segment                          0
# deceased_indicator                      0
# owns_car                                0
# tenure                                  0
# address                                 0
# postcode                                0
# state                                   0
# country                                 0
# property_valuation                      0
# Unnamed: 16                             0
# Unnamed: 17                             0
# Unnamed: 18                             0
# Unnamed: 19                             0
# Unnamed: 20                             0
# Rank                                    0
# ...

# %%
# from datetime import datetime,timedelta
# # df_n['d']=pd.to_datetime(df_n['DOB'])
# df_n['age']=(datetime.now()-df_n['d'])

# %%
# df['DOB'].replace(np.NaN,' ',inplace=True)

# %%
# df['DOB'].value_counts()

# %%
# df_n['net_age']=(df_n['age']//365)

# %%
# df_n['net_age']

# %%
# from datetime import datetime
# today = datetime.today()
# df['age'] = df['DOB'].apply(lambda x: (today - x).days // 365)

# %%
# df_n.age

# %%
(df_n['gender'].value_counts()).plot.bar()

# %%
from datetime import datetime,timedelta
today=datetime.today()

# %%
df_n['age']=df_n['DOB'].apply(lambda x:(today-x).days//365)

# %%
df_n.head()
# Out:
#   first_name  last_name gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister      M                                   86
# 1      Morly     Genery      M                                   69
# 2    Ardelis  Forrester      F                                   10
# 3     Lucine      Stutt      F                                   64
# 4    Melinda     Hadlee      F                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...    country  \
# 0      Mass Customer                  N      Yes  ...  Australia
# ...

# %%
bins=[18,25,50,60,180]
group=['teenager','adult','middle_aged', 'senior_citizen']

df_n['age_generation']=pd.cut(df_n['age'],bins,labels=group)

df_n[['age','age_generation']].head()
# Out:
#     age  age_generation
# 0  62.0  senior_citizen
# 1  50.0           adult
# 2  45.0           adult
# 3  41.0           adult
# 4  54.0     middle_aged

# %%
df_n.head()
# Out:
#   first_name  last_name gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister      M                                   86
# 1      Morly     Genery      M                                   69
# 2    Ardelis  Forrester      F                                   10
# 3     Lucine      Stutt      F                                   64
# 4    Melinda     Hadlee      F                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  property_valuation  \
# 0      Mass Customer                  N      Yes  ...                   6
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(x='age',data=df_n)

# %%
 (df_n['age_generation'].value_counts()).plot(kind='bar')

# %%
plt.scatter(y='job_industry_category',x='age',data=df_n)
plt.xlabel('age')
plt.ylabel('job_industry_category')
# Out:
# Text(0, 0.5, 'job_industry_category')

# %%
plt.scatter(x='age',y='Rank',data=df_n)

# %%
plt.scatter(y='gender',x='age',data=df_n)

# %%
plt.scatter(x='wealth_segment',y='age',data=df_n)

# %%
df_n.Rank.value_counts()
# Out:
# 760     13
# 259     12
# 455      9
# 904      9
# 386      9
#         ..
# 785      1
# 773      1
# 754      1
# 355      1
# 1000     1
# Name: Rank, Length: 324, dtype: int64

# %%
df_n.Rank.shape
# Out:
# (1000,)

# %%
df_n.describe(include='all')
# Out:
#        first_name last_name gender  past_3_years_bike_related_purchases  \
# count        1000      1000   1000                          1000.000000
# unique        940       962      3                                  NaN
# top        Dorian    np.NaN      F                                  NaN
# freq            3        29    513                                  NaN
# first         NaN       NaN    NaN                                  NaN
# last          NaN       NaN    NaN                                  NaN
# mean          NaN       NaN    NaN                            49.836000
# std           NaN       NaN    NaN                            27.796686
# min           NaN       NaN    NaN                             0.000000
# 25%           NaN       NaN    NaN                            26.750000
# 50%           NaN       NaN    NaN                            51.000000
# 75%           NaN       NaN    NaN                            72.000000
# ...

# %%
plt.scatter(y='age',x='owns_car',data=df_n)

# %%
plt.scatter(x='age',y='property_valuation',data=df_n)
plt.xlabel('age')
plt.ylabel('property_valuation')
# Out:
# Text(0, 0.5, 'property_valuation')

# %%
plt.scatter(x='age',y='Value',data=df_n)

# %%
df_n.head()
# Out:
#   first_name  last_name gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister      M                                   86
# 1      Morly     Genery      M                                   69
# 2    Ardelis  Forrester      F                                   10
# 3     Lucine      Stutt      F                                   64
# 4    Melinda     Hadlee      F                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  property_valuation  \
# 0      Mass Customer                  N      Yes  ...                   6
# ...

# %%
yt=(df_n['past_3_years_bike_related_purchases'].value_counts()).shape

# %%
t=(df_n['age'].value_counts())

# %%
j=df_n['age']

# %%
plt.bar(j,yt,data=df_n)
# Out:
# <BarContainer object of 1000 artists>

# %%
a=df_n['tenure']

# %%
plt.bar(a,j,data=df_n)
plt.xlabel('tenure')
# Out:
# Text(0.5, 0, 'tenure')

# %%
plt.bar(yt,a,data=df_n)
# Out:
# <BarContainer object of 1000 artists>

# %%
# plt.scatter(df_n['age'],df_n['gender'],data=df_n)

# %%
plt.hist('age',data=df_n,bins=50)
# Out:
# C:\Users\ISHAN MAHESHWARI\Miniconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\ISHAN MAHESHWARI\Miniconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([15., 18., 16., 32., 25., 16., 25., 23., 18.,  9., 18.,  9.,  8.,
#          8., 14., 17., 22., 38., 27., 28., 21., 54., 24., 19., 12., 33.,
#         11., 25., 38., 18., 14., 18., 36., 13., 19., 40., 17., 13., 15.,
#         38., 10.,  5., 22.,  9.,  7.,  9., 15., 10., 15., 17.]),
#  array([18.  , 19.28, 20.56, 21.84, 23.12, 24.4 , 25.68, 26.96, 28.24,
#         29.52, 30.8 , 32.08, 33.36, 34.64, 35.92, 37.2 , 38.48, 39.76,
#         41.04, 42.32, 43.6 , 44.88, 46.16, 47.44, 48.72, 50.  , 51.28,
#         52.56, 53.84, 55.12, 56.4 , 57.68, 58.96, 60.24, 61.52, 62.8 ,
# ...

# %%
df_n.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Unnamed: 16                                   float64
# ...

# %%
df_n.postcode.nunique()
# Out:
# 522

# %%
plt.scatter('property_valuation','postcode',data=df_n)
plt.xlabel('property_valuation')
plt.ylabel('postcode')
# Out:
# Text(0, 0.5, 'postcode')

# %%
plt.scatter('state','postcode',data=df_n)

# %%
import seaborn as sns
sns.boxplot(x='property_valuation',y='postcode',data=df_n)

# %%
plt.scatter('wealth_segment','tenure',data=df_n)

# %%
sns.pairplot(df_n)

# %%
df_n.corr()
# Out:
#                                      past_3_years_bike_related_purchases  \
# past_3_years_bike_related_purchases                             1.000000
# tenure                                                         -0.034183
# postcode                                                        0.015208
# property_valuation                                             -0.010833
# Unnamed: 16                                                     0.016977
# Unnamed: 17                                                     0.016574
# Unnamed: 18                                                     0.110817
# Unnamed: 19                                                     0.111829
# Unnamed: 20                                                    -0.004392
# Rank                                                           -0.004392
# Value                                                           0.004884
# age                                                            -0.020243
#
# ...

# %%
b=df_n['gender']
c=df_n['past_3_years_bike_related_purchases']

# %%
plt.bar(b,c,data=df_n)
plt.xlabel('gender')
plt.ylabel('past_3_years_bike_related_purchases')
# Out:
# Text(0, 0.5, 'past_3_years_bike_related_purchases')

# %%
plt.scatter('gender','past_3_years_bike_related_purchases',data=df_n)

# %%
sns.boxplot(x='gender',y='past_3_years_bike_related_purchases',data=df_n)

# %%
sns.boxplot(x='gender',y='tenure',data=df_n)

# %%
sns.violinplot(x='wealth_segment',y='past_3_years_bike_related_purchases',data=df_n)

# %%
sns.violinplot(y='job_industry_category',x='past_3_years_bike_related_purchases',data=df_n)

# %%
sns.boxplot(y='job_industry_category',x='past_3_years_bike_related_purchases',data=df_n)

# %%
plt.scatter('wealth_segment','tenure',data=df_n)

# %%
df_n['gender'].value_counts()
# Out:
# F    513
# M    470
# U     17
# Name: gender, dtype: int64

# %%
(df_n.groupby('gender')['past_3_years_bike_related_purchases']).plot(kind='bar')
# Out:
# gender
# F    AxesSubplot(0.125,0.125;0.775x0.755)
# M    AxesSubplot(0.125,0.125;0.775x0.755)
# U    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: past_3_years_bike_related_purchases, dtype: object

# %%
plt.plot('owns_car','past_3_years_bike_related_purchases',data=df_n)

# %%
plt.scatter('age','owns_car',data=df_n)

# %%
plt.scatter('wealth_segment','age',data=df_n)

# %%
(df_n['owns_car'].value_counts()).plot.hist()

# %%
(df_n['job_industry_category'].value_counts()).plot.bar()
plt.xlabel('job_industry_category')
# Out:
# Text(0.5, 0, 'job_industry_category')

# %%
plt.barh('job_industry_category','age',data=df_n)
plt.xlabel('age')
plt.ylabel('job_industry_category')
# Out:
# Text(0, 0.5, 'job_industry_category')

# %%
plt.bar('wealth_segment','age',data=df_n)
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.bar('wealth_segment','property_valuation',data=df_n)
# Out:
# <BarContainer object of 1000 artists>

# %%
(df_n['wealth_segment'].value_counts()).plot.bar()
plt.xlabel('wealth_segment')
# Out:
# Text(0.5, 0, 'wealth_segment')

# %%
plt.scatter('property_valuation','postcode',data=df_n)
plt.xlabel('property_valuation')
plt.ylabel('postcode')
# Out:
# Text(0, 0.5, 'postcode')

# %%
plt.scatter('state','postcode',data=df_n)

# %%
plt.scatter('past_3_years_bike_related_purchases','tenure',data=df_n)
plt.xlabel('past_3_years_bike_related_purchases')
plt.ylabel('tenure')
# Out:
# Text(0, 0.5, 'tenure')

# %%
plt.scatter('postcode','past_3_years_bike_related_purchases',data=df_n)
plt.ylabel('past_3_years_bike_related_purchases')
plt.xlabel('postcode')
# Out:
# Text(0.5, 0, 'postcode')

# %%
plt.scatter('age','tenure',data=df_n)
plt.xlabel('age')
plt.ylabel('tenure')
# Out:
# Text(0, 0.5, 'tenure')

# %%
# sns.jointplot('age','brand',data=df_n)

# %%
# plt.bar('past_3_years_bike_related_purchases','brand',data=df_n)

# %%
# plt.bar('brand','product_line',data=df_n)

# %%
plt.scatter('age','property_valuation',data=df_n)
plt.xlabel('age')
plt.ylabel('property_valuation')
# Out:
# Text(0, 0.5, 'property_valuation')

# %%
plt.scatter('age','tenure',data=df_n)
plt.xlabel('age')
plt.ylabel('tenure')
# Out:
# Text(0, 0.5, 'tenure')

# %%
plt.scatter('tenure','past_3_years_bike_related_purchases',data=df_n)
plt.xlabel('tenure')
plt.ylabel('past_3_years_bike_releated_purchases')
plt.title('total_purchase_threw_tenure')
# Out:
# Text(0.5, 1.0, 'total_purchase_threw_tenure')

# %%
plt.scatter('tenure','property_valuation',data=df_n)
plt.xlabel('tenure')
plt.ylabel('property_valuation')
# Out:
# Text(0, 0.5, 'property_valuation')

# %%
plt.scatter('property_valuation','past_3_years_bike_related_purchases',data=df_n)
plt.ylabel('past_3_years_bike_related_purchases')
plt.xlabel('property_valuation')
# Out:
# Text(0.5, 0, 'property_valuation')

# %%
(df_n['tenure'].value_counts()).plot(kind='hist')

# %%
plt.scatter('wealth_segment','age',data=df_n)

# %%
bins=[2000,3000,4000,5000]
group=['NSW','VIC','QLD']
df_n['postcode_labels']=pd.cut(df_n['postcode'],bins,labels=group)
df_n[['postcode','postcode_labels']].head()
# Out:
#    postcode postcode_labels
# 0      4500             QLD
# 1      2113             NSW
# 2      3505             VIC
# 3      4814             QLD
# 4      2093             NSW

# %%
# plt.plot('postcode_labels','past_3_years_bike_releated_purchases',data=df_n)

# %%
plt.scatter('gender','past_3_years_bike_related_purchases',data=df_n)
plt.xlabel('gender')
plt.ylabel('past_3_years_bike_related_purchases')
# Out:
# Text(0, 0.5, 'past_3_years_bike_related_purchases')

# %%
plt.bar('gender','past_3_years_bike_related_purchases',data=df_n)
# Out:
# <BarContainer object of 1000 artists>

# %%
import seaborn as sns
sns.boxplot(x='gender',y='age',data=df_n,hue='wealth_segment')

# %%
# sns.lmplot(x='owns_car',y='age',data=df_n)

# %%
# sns.jointplot(x='gender',y='past_3_years_bike_related_purchases',data=df_n,hue='wealth_segment')

# %%
sns.boxplot(x='state',y='postcode',data=df_n,hue='property_valuation')

# %%
(df_n.groupby('state')['owns_car'].count()).plot.bar()

# %%
# (df_n.groupby('owns_car')).plot.bar()

# %%
plt.scatter('gender','past_3_years_bike_related_purchases',data=df_n)
plt.xlabel('gender')
# Out:
# Text(0.5, 0, 'gender')

# %%
plt.plot('gender','past_3_years_bike_related_purchases',data=df_n)
plt.xlabel('gender')
# Out:
# Text(0.5, 0, 'gender')
